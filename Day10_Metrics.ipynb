# %% [markdown]
# #Metrics Definition:
# In machine learning (ML), metrics are numbers that help us understand how well a model is working. They measure how accurate or correct the model's predictions are. For example, if a model predicts whether an email is spam or not, a metric like accuracy tells us how many times it got the prediction right. Other metrics like precision, recall, and F1-score give more details about performance, especially when the data is imbalanced. These metrics help us compare models, find mistakes, and choose the best one for the task. Simply put, metrics show how good (or bad) a machine learning model is.

# %% [markdown]
# # Metrics Techniques In Regression:
# 1.Mean Squared Error (MSE)
#
# 2.Root Mean Square Error (RMSE)
#
# 3.Mean Absolute Error (MAE)
#
#
# 4.The R² score

# %% [markdown]
# #**1. Mean Square Error(MSE)**
# Mean Squared Error (MSE) is a common evaluation metric for regression models. It measures the average of the squares of the differences between the actual and predicted values.
#
# ![mse.png](data:image/png;base64,...)
#
# #**2. Root Mean Square Error(RMSE)**
# RMSE tells us how far off the model’s predictions are from the actual values, on average. It does this by:
#
# a.Finding the difference between each prediction and the actual value.
#
# b.Squaring those differences (to remove negative signs).
#
# c.Taking the average of the squared differences.
#
# d.Taking the square root of that average.
#
#
#   ![download.png](data:image/png;base64,...)

# %% [markdown]
# #**3. Mean Absolute Error(MAE)**
# Mean Absolute Error (MAE) is a widely-used metric in regression analysis that measures the average of the absolute errors between predicted and actual values. It provides a straightforward indication of how close the predicted values are to the actual values.
#
# ![mae.png](data:image/png;base64,...)

# %% [markdown]
# #**4.The R² score**
# The R² score, also known as the coefficient of determination, is a key metric in regression analysis that measures how well the predictions from a model match the actual data points. It provides a measure of how much of the variance in the target variable can be explained by the model's features.
#
# ![download (1).png](data:image/png;base64,...)

# %% [markdown]
# #**Metrics Techniques in Classification**
# #Classification Report:
#
# a.Confusion Matrix
#
# b.Accuracy
#
# c.Precission
#
# d.Recall
#
# e.F1 Score

# %% [markdown]
# #a.Confusion Matrix:
#
# A **confusion matrix** is a table used to evaluate the performance of a **classification model** by comparing actual and predicted labels. It shows how many predictions were correct and where the model made errors. The matrix has four main parts: **True Positives (TP)**, **True Negatives (TN)**, **False Positives (FP)**, and **False Negatives (FN)**. For example, in binary classification, TP means the model correctly predicted the positive class. It helps calculate metrics like **accuracy**, **precision**, **recall**, and **F1-score**. A confusion matrix provides a clear, detailed view of model performance beyond a single number like accuracy.

# %% [markdown]
# ![confusion.ppm](data:application/octet-stream;base64,...)

# %% [markdown]
# #**b.Accuracy**
# Accuracy means how correct or exact something is. If something is accurate, it is very close to the right answer or the truth. For example, if you guess someone’s age and your guess is very close to their real age, your guess is accurate. Accuracy is important in schoolwork, science, measurements, and even everyday tasks because it helps people make good decisions and avoid mistakes. Being accurate means doing things carefully and checking your work to make sure it's right.
#
# ![acc.png](data:image/png;base64,...)

# %% [markdown]
# #**c.Precission**
# Precision means doing something the same way every time and getting similar results. It shows how consistent you are. For example, if you throw a ball and it always lands in the same spot, you are being precise, even if it's not the right spot. Precision is about being steady and careful, not just being correct. It's important when you want to repeat something and get the same outcome each time.

# %% [markdown]
# ![precision-formula.png](data:image/png;base64,...)

# %% [markdown]
# #**d.Recall**
# In machine learning, recall is a performance metric used to measure how well a model can identify all relevant instances, especially in classification problems. It is the ratio of correctly predicted positive observations to all the actual positives. In other words, recall tells you how many of the actual positive cases the model was able to find.
#
# ![recall.png](data:image/png;base64,...)

# %% [markdown]
# #**e.F1 Score**
# The **F1 score** is a way to measure how well a machine learning model is performing by combining **precision** and **recall**. Precision shows how many of the predicted positive results were actually correct, while recall tells us how many actual positive cases the model correctly found. The F1 score takes both into account and gives a single number that balances these two metrics. It’s especially helpful when there’s an imbalance in the data, meaning one type of result (like positive cases) is rarer than the other. A higher F1 score means the model is doing well in both areas.
#
# ![f1.png](data:image/png;base64,...)

# %% [markdown]
# #**Support Vector Machine**
# Support Vector Machine (SVM) is a machine learning algorithm used to classify data into different categories. It works by drawing a line (or boundary) that separates the data points of different categories in the best possible way. The goal is to make sure the distance between the line and the closest data points (called support vectors) is as large as possible. This helps the model make better predictions. SVM can handle both simple and complex data patterns and is used in tasks like image recognition, spam detection, and medical diagnosis because it's accurate and reliable.

# %% [markdown]
# ![svm.png](data:image/png;base64,...)

# %% [markdown]
# #**KNN (K Nearest Neighbours)**
# The **K-Nearest Neighbors (KNN)** algorithm is a simple, supervised machine learning method used for classification and regression. It works by comparing a new data point to existing data points and finding the **'k' closest neighbors** based on distance (like Euclidean distance). The new point is then classified based on the most common category among its neighbors (for classification) or averaged values (for regression). KNN doesn’t learn from the data during training—instead, it stores the entire dataset and makes decisions at prediction time. It’s easy to understand and use, but can be slow with large datasets or high dimensions.

# %% [markdown]
# ![knn.png](data:image/png;base64,...)

# %% [markdown]
# #**Decision Trees**
# A **Decision Tree** is a supervised machine learning algorithm used for both classification and regression tasks. It works like a flowchart, where each internal node represents a decision based on a feature, each branch shows the outcome of the decision, and each leaf node represents the final prediction or class label. The tree splits the data into smaller and smaller groups based on questions about the features, aiming to make the groups as pure as possible. Decision trees are easy to understand and visualize, but they can overfit if the tree is too deep. Techniques like pruning help prevent this.
# # Structure of decision tree
#
#
# Root Node: The starting point that represents the entire dataset.
#
# Decision/Internal Nodes: Represent tests or decisions based on features.
#
# Branches: Outcomes of the decisions.
#
# Leaf Nodes: Final output labels (classes or values).

# %% [markdown]
# ![ai18.jfif](data:image/jpeg;base64,...)
